# %%
import numpy as np



n_type=20

l=2

N=l*l*l

p=np.zeros([n_type,N,3])

p[0,0,:]=np.array([0.5000000 ,  0.0000000 ,  0.0000000])/l
p[1,0,:]=np.array([0.0000000 ,  0.5000000 ,  0.5000000])/l
p[2,0,:]=np.array([0.5000000 ,  0.0000000 ,  0.5000000])/l
p[3,0,:]=np.array([0.0000000 ,  0.5000000 ,  0.0000000])/l
p[4,0,:]=np.array([0.9930000 ,  0.0297000 ,  0.2500000])/l
p[5,0,:]=np.array([0.0070000 ,  0.9703000 ,  0.7500000])/l
p[6,0,:]=np.array([0.5070000 ,  0.5297000 ,  0.2500000])/l
p[7,0,:]=np.array([0.4930000 ,  0.4703000 ,  0.7500000])/l
p[8,0,:]=np.array([0.7190000 ,  0.3020000 ,  0.0290000])/l
p[9,0,:]=np.array([0.2810000 ,  0.6980000 ,  0.5290000])/l
p[10,0,:]=np.array([0.7810000 ,  0.8020000 ,  0.4710000])/l
p[11,0,:]=np.array([0.2810000 ,  0.6980000 ,  0.9710000])/l
p[12,0,:]=np.array([0.7810000 ,  0.8020000 ,  0.0290000])/l
p[13,0,:]=np.array([0.7190000 ,  0.3020000 ,  0.4710000])/l
p[14,0,:]=np.array([0.2190000 ,  0.1980000 ,  0.5290000])/l
p[15,0,:]=np.array([0.2190000 ,  0.1980000 ,  0.9710000])/l
p[16,0,:]=np.array([0.0800000 ,  0.4850000 ,  0.2500000])/l
p[17,0,:]=np.array([0.9200000 ,  0.5150000 ,  0.7500000])/l
p[18,0,:]=np.array([0.4200000 ,  0.9850000 ,  0.2500000])/l
p[19,0,:]=np.array([0.5800000 ,  0.0150000 ,  0.7500000])/l


cell_n=1
for i in range(l):
    for j in range(l):
       for k in range(l):
           if i!=0 or j!=0 or k!=0:
              for m in range(n_type):
                  p[m,cell_n,:]= p[m,0,:]+ np.array([i/l,j/l,k/l])
              cell_n=cell_n+1



for i in range(N):
    for m in range(n_type):
        if m==0 or m==1 :
           atom='Fe1'
           print("%5s %10.7f  %10.7f  %10.7f" % (atom, p[m,i,0], p[m,i,1], p[m,i,2]))
for i in range(N):
    for m in range(n_type):
        if  m==2 or m==3:
           atom='Fe2'
           print("%5s %10.7f  %10.7f  %10.7f" % (atom, p[m,i,0], p[m,i,1], p[m,i,2]))
for i in range(N):
    for m in range(n_type):
        if m==4 or m==5 or m==6 or m==7:
           atom='La'
           print("%5s %10.7f  %10.7f  %10.7f" % (atom, p[m,i,0], p[m,i,1], p[m,i,2]))
for i in range(N):
    for m in range(n_type):
        if m==8 or m==9 or m==10 or m==11 or m==12 or m==13 or m==14 or m==15 or m==16 or m==17 or m==18 or m==19:
           atom='O'
           print("%5s %10.7f  %10.7f  %10.7f" % (atom, p[m,i,0], p[m,i,1], p[m,i,2]))
# Out:
#   Fe1  0.2500000   0.0000000   0.0000000
#   Fe1  0.0000000   0.2500000   0.2500000
#   Fe1  0.2500000   0.0000000   0.5000000
#   Fe1  0.0000000   0.2500000   0.7500000
#   Fe1  0.2500000   0.5000000   0.0000000
#   Fe1  0.0000000   0.7500000   0.2500000
#   Fe1  0.2500000   0.5000000   0.5000000
#   Fe1  0.0000000   0.7500000   0.7500000
#   Fe1  0.7500000   0.0000000   0.0000000
#   Fe1  0.5000000   0.2500000   0.2500000
#   Fe1  0.7500000   0.0000000   0.5000000
#   Fe1  0.5000000   0.2500000   0.7500000
#   Fe1  0.7500000   0.5000000   0.0000000
#   Fe1  0.5000000   0.7500000   0.2500000
#   Fe1  0.7500000   0.5000000   0.5000000
#   Fe1  0.5000000   0.7500000   0.7500000
#   Fe2  0.2500000   0.0000000   0.2500000
#   Fe2  0.0000000   0.2500000   0.0000000
#   Fe2  0.2500000   0.0000000   0.7500000
#   Fe2  0.0000000   0.2500000   0.5000000
#   Fe2  0.2500000   0.5000000   0.2500000
#   Fe2  0.0000000   0.7500000   0.0000000
#   Fe2  0.2500000   0.5000000   0.7500000
# ...
